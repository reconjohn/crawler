# %%
# A demo of collecting data from YouTube.

from selenium import webdriver
from bs4 import BeautifulSoup
import time, datetime, csv


# The url where the data will be collected from.
url = "https://www.youtube.com/results?search_query=energy+justice"

# A bot can automate the collecting data process. A bot will iminate how an user browse a web page, and then acqure those
# useful information. Therefore, a bot needs to control a browser. Google has released the driver to enable software
# engineerer to control a chrame application. Please download the chromedrive from https://chromedriver.chromium.org/downloads.
# Please make sure you pick the right version (the version of the latest chrome browser is 89.X). the "executable_path"
# indicates the location where you store the driver.
bot = webdriver.Chrome(executable_path="chromedriver/chromedriver")

# Input the targeting url to the bot, and the bot will load data from the url.
bot.get(url)

# Create a csv file to store the structured data after processing.
csvfile = open("assets/utube.csv", "w", newline='', encoding="utf-8") # mode a, r, w   absoluate path, relative patgh

# All the fields of each data entry that I want to collect.
fieldnames = ['username', 'user_url', 'title', 'view_num', 'created_at', 'video_url', 'shortdesc', 'collected_at', 'img_url']

# Create a writer to write the structured data to the csv file.
writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

# Write the header to the csv file
writer.writeheader()

# An array to store all the video urls.
video_urls = []


# variable i indicates the number of times that scrolls down a web page. In practice, you might want to develop different
# interaction approach to load and view the web pages.

for i in range(4):

    # Create a document object model (DOM) from the raw source of the crawled web page.
    # Since you are processing a html page, 'html.parser' is chosen.
    soup = BeautifulSoup(bot.page_source, 'html.parser')

    # Capture all the video items using find_all or findAll method.
    # To view the information of the html elements you want to collect, you need to inspect the raw source using Chrome Inspector.
    # To test whether you find the right html elements, you can use the pycharm debugger to examine the returned data.
    videos = soup.find_all('ytd-video-renderer', class_="style-scope ytd-item-section-renderer")[-20:] # 20 indicates only process the newly-acquired 20 entries.

    # iterate and process each video entry.
    for video in videos:

        # I prefer use the "try-except" statement to enable the program run without pausing due to unexecpted errors.
        try:
            video_url = video.find("a", class_="yt-simple-endpoint inline-block style-scope ytd-thumbnail").attrs["href"]
            img_url = video.find("img", class_="style-scope yt-img-shadow").attrs["src"]
            user_url = video.find("a", class_="yt-simple-endpoint style-scope yt-formatted-string").attrs["href"]
            username = video.find("a", class_="yt-simple-endpoint style-scope yt-formatted-string").text
            title = video.find("yt-formatted-string", class_="style-scope ytd-video-renderer").text
            view_num = video.find_all("span", class_="style-scope ytd-video-meta-block")[0].text.replace(" views", "")
            created_at = video.find_all("span", class_="style-scope ytd-video-meta-block")[1].text.replace(" ago", "")
            shortdesc = video.find("yt-formatted-string", id="description-text").text
            collected_at = datetime.datetime.now()

            # create a row in the dict format.
            row = {'video_url': video_url,
                    'user_url': user_url,
                    'username': username,
                    'title': title,
                    'view_num': view_num,
                    'created_at': created_at,
                    'shortdesc': shortdesc,
                    'img_url': img_url,
                    'collected_at': collected_at}

            # if a video has been added to the csvfile, this video would not be inserted to the csv file,
            # otherwise, this video will be inserted.
            if video_url in video_urls:
                print("this video has already been added.")
            else:
                print(row)
                writer.writerow(row)

                # add the video_url to the video_urls array.
                video_urls.append(video_url)
        except:
            pass

    # it is very important to enable the bot take some rest, and then resume to work.
    time.sleep(5)

    # Let the bot scrolls down to the bottom of the content element, most of the time the bot needs to scroll down to the bottom of the page.
    # like this statement: bot.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    bot.execute_script('window.scrollTo(0,  document.getElementById("content").scrollHeight);')

# close the csvfile object and the bot object.
csvfile.close()
bot.close()

# notify the completion of the program in the console.
print("finished")
# Out:
# {'video_url': '/watch?v=9CfWH25PIp0', 'user_url': '/user/greenbiz', 'username': 'GreenBiz', 'title': 'VERGE Talk: Connecting the dots - why energy justice matters', 'view_num': '636', 'created_at': '3 years', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/9CfWH25PIp0/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAzSiDw_wEiKQ0OPS3x58MXptJ3Kw', 'collected_at': datetime.datetime(2021, 4, 18, 23, 23, 54, 971927)}
# {'video_url': '/watch?v=rS4XEa-hgts', 'user_url': '/channel/UCW3j8gqJ_mAfbbTtRHgFLdA', 'username': 'UC Davis Energy', 'title': 'The Past, Present and Future of Energy Justice', 'view_num': '132', 'created_at': '5 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/rS4XEa-hgts/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCjYqlAy2S-6WiocCbzGGZrtcGA9w', 'collected_at': datetime.datetime(2021, 4, 18, 23, 23, 54, 975918)}
# {'video_url': '/watch?v=iO4D7jCF6Xg', 'user_url': '/user/GundInstitute', 'username': 'Gund Institute for Environment', 'title': 'Michael Dorsey: Delivering 21st Century Energy Justice', 'view_num': '150', 'created_at': '4 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/iO4D7jCF6Xg/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCXoM2GGem4gsUB3O_Dl6Um7xRbrA', 'collected_at': datetime.datetime(2021, 4, 18, 23, 23, 54, 979916)}
# {'video_url': '/watch?v=OTH0G3sVqEU', 'user_url': '/user/FuquaSchOfBusiness', 'username': 'Duke University - The Fuqua School of Business', 'title': 'Duke University Energy Conference: Michael Dworkin on Conceptualizing Energy Justice', 'view_num': '681', 'created_at': '4 years', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/OTH0G3sVqEU/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBB5VKPlBuzyElImrBaZYyrN3xIsg', 'collected_at': datetime.datetime(2021, 4, 18, 23, 23, 54, 984841)}
# {'video_url': '/watch?v=KDVVL8X3W90', 'user_url': '/channel/UCv0uKKTJ46HyoiebqH7xPEQ', 'username': 'Dr. Victoria R Nalule', 'title': 'Global Energy Justice', 'view_num': '448', 'created_at': '1 year', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/KDVVL8X3W90/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC3I9PYByZ2jVXvkts9MBvXA6gqyA', 'collected_at': datetime.datetime(2021, 4, 18, 23, 23, 54, 988831)}
# this video has already been added.
# this video has already been added.
# this video has already been added.
# this video has already been added.
# this video has already been added.
# {'video_url': '/watch?v=IT90KzkFwwA', 'user_url': '/user/eCornellOnline', 'username': 'eCornell', 'title': 'Energy Justice: Exploring an Equitable Green Transition', 'view_num': '50', 'created_at': 'Streamed 4 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/IT90KzkFwwA/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAfmOlK3loSO1f9YrdQ5U65OjQtQQ', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 1, 616004)}
# {'video_url': '/watch?v=aP32nm2YPFU', 'user_url': '/channel/UCv0uKKTJ46HyoiebqH7xPEQ', 'username': 'Dr. Victoria R Nalule', 'title': 'Energy Justice & Fossil Fuels (1/5)', 'view_num': '351', 'created_at': '2 years', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/aP32nm2YPFU/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA8Ucah45hAulAClRAynByGd8mq5g', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 1, 621989)}
# {'video_url': '/watch?v=04-LZE0kaBA', 'user_url': '/user/VermontLawSchool', 'username': 'Vermont Law School', 'title': 'VJEL Symposium: Clean Energy Justice Panel', 'view_num': '21', 'created_at': '5 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/04-LZE0kaBA/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDRoRACcSfUiyc9CCqeWSbC0yXs6Q', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 1, 625980)}
# {'video_url': '/watch?v=xPrguCM-OoU', 'user_url': '/channel/UCvft8oa1xcBrIN45YFsXpBA', 'username': 'Energy Justice For All', 'title': 'Demand Energy Justice: Animated Video', 'view_num': '539', 'created_at': '2 years', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/xPrguCM-OoU/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA-WoT8aeNNjTAYBS_UxnlU7UiLFQ', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 1, 628969)}
# {'video_url': '/watch?v=LvRPxcQgdLc', 'user_url': '/user/BahaiChair', 'username': "The Bahá'í Chair for World Peace", 'title': 'Indigenous Energy Justice: Dr. Kyle Powys Whyte (Global Climate Crisis Conference)', 'view_num': '303', 'created_at': '11 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/LvRPxcQgdLc/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCF8UfNX22j09uMsi2bhHkhUs1Kmg', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 1, 631961)}
# this video has already been added.
# {'video_url': '/watch?v=mRT-s7NAF4s', 'user_url': '/user/greeneuropeanfdn', 'username': 'Green European Foundation', 'title': 'Christine Milchram - Smart Grids and Energy Justice', 'view_num': '324', 'created_at': '9 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/mRT-s7NAF4s/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB6JqGymS1-8AGrusojCU_cjKnBmQ', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 9, 113067)}
# {'video_url': '/watch?v=daDBzNESpxA', 'user_url': '/channel/UCrh_s7ejffI7tDz6gus2nbw', 'username': "Carnegie Mellon University's Scott Institute for Energy Innovation", 'title': 'Justice in the Energy Transition', 'view_num': '3', 'created_at': '3 days', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/daDBzNESpxA/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCAXdWbJcel5cFbpzEAnLpvMhXcCQ', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 9, 117097)}
# {'video_url': '/watch?v=AEKyZyec_m4', 'user_url': '/channel/UCiKFyG2M8e62HOrDDJ7HYbw', 'username': 'Wedge LIVE!', 'title': 'Ward 7 Forum: Local Climate, Housing, Energy Justice', 'view_num': '131', 'created_at': 'Streamed 3 years', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/AEKyZyec_m4/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLC4NGqHhzjNcqaF49IuDvMIQgsZtA', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 9, 123081)}
# {'video_url': '/watch?v=-zjCmMkEiMw', 'user_url': '/user/ThinkTechHawaii', 'username': 'ThinkTech Hawaii', 'title': 'Energy Justice with Shalanda Baker, Tim Vandeveer and Caroline Carl', 'view_num': '126', 'created_at': '5 years', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/-zjCmMkEiMw/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCgWVJEP8M9Aa5FpzZVKOqTs0wZmg', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 9, 127081)}
# {'video_url': '/watch?v=hvFXKhnEiEQ', 'user_url': '/channel/UCSEeJiklGuaTrWYi0UulacQ', 'username': 'Center for Progressive Reform', 'title': 'Climate, Energy, Justice: Transportation Policy', 'view_num': '13', 'created_at': '2 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/hvFXKhnEiEQ/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBwkpZEEznr6_SqLELo95bN_a4E4w', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 9, 131059)}
# {'video_url': '/watch?v=WNKMHAyjbqs', 'user_url': '/channel/UCSEeJiklGuaTrWYi0UulacQ', 'username': 'Center for Progressive Reform', 'title': 'Climate, Energy, Justice: Electricity Policy', 'view_num': '11', 'created_at': '2 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/WNKMHAyjbqs/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB8cjp0xEfTOscv2qJEi5uhktVVVQ', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 9, 136005)}
# this video has already been added.
# {'video_url': '/watch?v=fBfCUbSeeSE', 'user_url': '/channel/UCG61srtwaX3AObPL-sw7Mdg', 'username': 'Megan Fulhorst', 'title': 'Energy Justice and Climate Change', 'view_num': '23', 'created_at': '6 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/fBfCUbSeeSE/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBPf1ip48iuXZCd7mmXjidrLs6xDw', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 15, 971317)}
# {'video_url': '/watch?v=S7CiHw16fp0', 'user_url': '/user/UHABNYC', 'username': 'UHABNYC', 'title': 'Community Solutions for Energy Justice', 'view_num': '4', 'created_at': '5 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/S7CiHw16fp0/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDvcsL5VzhS0Tuy8fIvdm0cadMD_w', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 15, 973278)}
# {'video_url': '/watch?v=kdNy-ADcyhY', 'user_url': '/channel/UC0wBeDtxuKb7B9kUQuumheA', 'username': 'Pecan Street', 'title': 'Pecan Street Race and Energy Webinar II August 5, 2020', 'view_num': '121', 'created_at': '8 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/kdNy-ADcyhY/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDo44N0iqlCtEm3omFGBLxB0Ssc-w', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 15, 978300)}
# {'video_url': '/watch?v=XFnAF7QUzQo', 'user_url': '/channel/UCDj97_kFFCQrq4005hDNjpA', 'username': 'Environment Boston', 'title': 'Vietnamese Energy Justice Webinar', 'view_num': '11', 'created_at': '5 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/XFnAF7QUzQo/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDTtT0vaa32HML6QFwPztdxt6mphw', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 15, 982288)}
# {'video_url': '/watch?v=Oosseq0ljL0', 'user_url': '/channel/UChB1LZACuG-V-xZgYLykKHg', 'username': 'Sara Bower', 'title': 'Energy Justice Colloquium', 'view_num': '12', 'created_at': '4 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/Oosseq0ljL0/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB07bhKWzSUrvmtbRLdRcjB1HH8oA', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 15, 985246)}
# {'video_url': '/watch?v=6BUphb0L8HY', 'user_url': '/channel/UCAsjyUoHRgCA5oHVfwvcGhg', 'username': 'Vision Makers Entertainment', 'title': 'PM Modi : India Energy Plans Aims to Ensure Energy Justice _ LIVE Speech _ VM News HD', 'view_num': '39', 'created_at': '5 months', 'shortdesc': '', 'img_url': 'https://i.ytimg.com/vi/6BUphb0L8HY/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA4xNHf119lap3bSDyD34hx03BNuA', 'collected_at': datetime.datetime(2021, 4, 18, 23, 24, 15, 988237)}
# finished

# %%
# Search tweets of a specific topic using a web crawler

from selenium import webdriver
from bs4 import BeautifulSoup
import time, datetime, json


# url = "https://twitter.com/search?l=&q=near%3A%22houston%22%20within%3A15mi%20since%3A2017-08-24%20until%3A2017-08-31&src=typd&lang=en"  #crawlling all the tweets posted near Houston during the Hurricane Harvey attacked period.
url = "https://twitter.com/search?f=tweets&vertical=news&q=seattle&src=typd&lang=en"

# use a chrome core. https://chromedriver.chromium.org/downloads
bot = webdriver.Chrome(executable_path="chromedriver/chromedriver") # if you are a mac user, please use "assets/chromedriver"
bot.get(url)

f = open("tweets.csv", "a", encoding="utf-8")
f.write('user_id, user_name, screen_name, status_id, created_at, time_integer, reply_num, retweet_num, favorite_num, content \n')
start = datetime.datetime.now()
time_limit = 60
texts = []

# Read the Xpath tutorial if you are not familiar with XPath.
# "//" operator indicates Selects nodes in the document from the current node that match the selection no matter where they are.
while len(bot.find_elements_by_xpath('//div[contains(text(), "Back to top ↑")]')) != 1:
    time.sleep(5)
    bot.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    soup = BeautifulSoup(bot.page_source, 'html.parser')
    tweets = soup.find_all('li', class_="stream-item")[-20:] # only process the newly-acquired tweets.
    if int((datetime.datetime.now() - start).seconds) >= time_limit: # if longer than a minute, then stop scrolling.
        break
    for tweet in tweets:
        try:
            user_json = json.loads(tweet.div.attrs["data-reply-to-users-json"])
            user_id = int(user_json[0]['id_str'])
            user_name = user_json[0]['screen_name']
            screen_name = user_json[0]['name']
            status_id = int(tweet.attrs["data-item-id"])
            text = tweet.find("p").text.strip().replace("\n", "")
            created_at = tweet.find("small", class_="time").a.attrs["title"]
            time_integer = tweet.find("small", class_="time").a.span["data-time-ms"]
            reply_num = tweet.find("div", class_="ProfileTweet-action--reply").find("span", class_="ProfileTweet-actionCountForPresentation").text
            retweet_num = tweet.find("div", class_="ProfileTweet-action--retweet").find("span", class_="ProfileTweet-actionCountForPresentation").text
            favorite_num = tweet.find("div", class_="ProfileTweet-action--favorite").find("span", class_="ProfileTweet-actionCountForPresentation").text
            inst_url = ""
            if "www.instagram.com" in text:
                inst_url = tweet.p.a.attrs["title"]
            record = '%d, %s, %s, %d, %s， %s， %s， %s， %s， %s \n' % (user_id, user_name, screen_name, status_id, created_at, time_integer, reply_num, retweet_num, favorite_num, text)
            print(record)
            if (text not in texts):
                f.write(record)
            texts.append(text)
        except:
            pass
f.close()
bot.close()
print("finished")

if __name__ == "__main__":
    pass
# Out:
# finished

# %%
# Search existing tweets
# @reference: https://www.earthdatascience.org/courses/use-data-open-source-python/intro-to-apis/twitter-data-in-python/


import tweepy, json, time, csv

# Create a csv file to store the structured data after processing.
csvfile = open("assets/tweets.csv", "w", newline='', encoding="utf-8") # mode a, r, w

# All the fields of each data entry that I want to collect.
fieldnames = ['username', 'userid', 'profile_location', 'created_at', 'text', 'retweet_count', 'source', 'coordinates']

# Create a writer to write the structured data to the csv file.
writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
# Write the header to the csv file
writer.writeheader()


# Apply for your own Twitter API keys at https://developer.twitter.com/en/apply-for-access
consumer_key = "AuqhYPEBSFigdrFzfqUzHoEov"
consumer_secret = "drIf06K8SNpgtjBOv7WfRIfBySs5rsISIHuQKh2awuHGjZdsZQ"
access_token = "179512083-toy8Ejm6j2BK8I7dkeYnp2V0r8t6yUFO92m10KRf"
access_token_secret = "d6mTUs2FBFCwDbc9WHvMoBRjk2ISES0RVYDGWVIOGhpR3"


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# Define the search term and the date_since date as variables
search_words = "#energy"
location = "47.6138893,-122.3107869,3000mi"
# read the Twitter API document to look for other ways to customize your queries.
# refer to https://developer.twitter.com/en/docs/twitter-api/v1/rules-and-filtering/search-operators
# for example: you can ignore all the retweets by #wildfires -filter:retweets
# Geolocalization: the search operator “near” isn’t available in the API, but there is a more precise way to restrict
# your query by a given location using the geocode parameter specified with the template “latitude,longitude,radius”,
# for example, “47.6138893,-122.3107869,10mi” (capitol hill at Seattle). When conducting geo searches, the search API will first attempt to find Tweets、
# which have lat/long within the queried geocode, and in case of not having success, it will attempt to find Tweets created
# by users whose profile location can be reverse geocoded into a lat/long within the queried geocode, meaning that is possible
# to receive Tweets which do not include lat/long information.

date_since = "2018-1-1"


# Collect tweets
# tweets = tweepy.Cursor(api.search, q=search_words, lang="en", since=date_since).items(100)
tweets = tweepy.Cursor(api.search, q=search_words, geocode=location, lang="en", since=date_since).items(100)

# Iterate and print tweets
for tweet in tweets:
    row = {
        'username': tweet.author.name,
        'userid': tweet.author.id,
        'profile_location': tweet.author.location,
        'created_at': str(tweet.author.created_at),
        'text': tweet.text,
        'retweet_count': tweet.retweet_count,
        'source': tweet.source,
        'coordinates': tweet.coordinates
    }
    writer.writerow(row)
    print(row)


csvfile.close()
# notify the completion of the program in the console.
print("finished")
# Out:
# {'username': 'Caligirl 🕊', 'userid': 189806241, 'profile_location': 'Dying Earth', 'created_at': '2010-09-12 08:06:07', 'text': 'RT @elleprovocateur: Initiatives such as https://t.co/DjNoghFw8m, coupled w/ branded terms  \n#NaturalClimateSolutions &amp; #naturebasedsolutio…', 'retweet_count': 12, 'source': 'Twitter for iPhone', 'coordinates': None}
# {'username': 'Randy Chatterjee', 'userid': 966645925, 'profile_location': 'Salish Territory, Cascadia', 'created_at': '2012-11-23 18:51:38', 'text': 'RT @A_Better_City: #green #energy #resilience PARTICIPATE and LEARN! https://t.co/H42xm7HZDn', 'retweet_count': 1, 'source': 'Twitter for Mac', 'coordinates': None}
# {'username': 'A Better City', 'userid': 2472716287, 'profile_location': 'Vancouver, BC, Canada', 'created_at': '2014-05-01 15:59:54', 'text': '#green #energy #resilience PARTICIPATE and LEARN! https://t.co/H42xm7HZDn', 'retweet_count': 1, 'source': 'Twitter for Mac', 'coordinates': None}
# {'username': 'Association of Electrical Engineering Students', 'userid': 1361613789406392323, 'profile_location': 'Nigeria', 'created_at': '2021-02-16 09:50:09', 'text': 'RT @studentenergy: .@EnergyPortraits is collecting 📸photographs and stories related to the theme of #energy for the third and final round o…', 'retweet_count': 0, 'source': 'Twitter for Android', 'coordinates': None}
# {'username': 'Claus', 'userid': 185695656, 'profile_location': 'Pittsburgh', 'created_at': '2010-09-01 16:24:22', 'text': 'RT @a_yulana: Still Jumpin’  #fitness #FitnessMotivation #fit #FitnessGirl #JumpRopeChallenge #workoutmotivation #workouts #workout #workou…', 'retweet_count': 2, 'source': 'Twitter for Android', 'coordinates': None}
# {'username': 'Cardiology Bot', 'userid': 1327706800813182976, 'profile_location': 'Kepler-452b', 'created_at': '2020-11-14 20:15:49', 'text': 'RT @a_yulana: Still Jumpin’  #fitness #FitnessMotivation #fit #FitnessGirl #JumpRopeChallenge #workoutmotivation #workouts #workout #workou…', 'retweet_count': 2, 'source': 'cardiobot2', 'coordinates': None}
# {'username': 'Yuliya Gallimore', 'userid': 2465092215, 'profile_location': 'Florida', 'created_at': '2014-04-06 15:24:06', 'text': 'Still Jumpin’  #fitness #FitnessMotivation #fit #FitnessGirl #JumpRopeChallenge #workoutmotivation #workouts… https://t.co/qV9gxEekUs', 'retweet_count': 2, 'source': 'Twitter for iPhone', 'coordinates': None}
# {'username': 
# {'username': 'the404code', 'userid': 1310836644946145286, 'profile_location': '', 'created_at': '2020-09-29 06:59:57', 'text': "RT @AcooEdi: How (and why) cyber specialists hacked a North American utility's smart meter https://t.co/lqscgSbjPz #Technology #criticalinf…", 'retweet_count': 1, 'source': 'the404codeBot', 'coordinates': None}
# {'username': 'EdiAcoo', 'userid': 1002585844958597120, 'profile_location': 'Canadá', 'created_at': '2018-06-01 16:21:07', 'text': "How (and why) cyber specialists hacked a North American utility's smart meter https://t.co/lqscgSbjPz #Technology… https://t.co/JOgBU3npa7", 'retweet_count': 1, 'source': 'dlvr.it', 'coordinates': None}
# finished

# %%
# Search geo-tagged tweets within the U.S. This script is modified from https://github.com/shawn-terryah/Twitter_Geolocation


import tweepy, json, time, csv

class StreamListener(tweepy.StreamListener):
    """tweepy.StreamListener is a class provided by tweepy used to access
    the Twitter Streaming API to collect tweets in real-time.
    """

    def __init__(self, time_limit=30, file=""):
        """class initialization"""
        self.start_time = time.time()
        self.limit = time_limit
        self.f = open(file, "w", newline='', encoding="utf-8") # mode a, r, w
        fieldnames = ['id', 'username', 'created_at', 'lng', 'lat', 'text']
        self.writer = csv.DictWriter(self.f, fieldnames=fieldnames)
        self.writer.writeheader()
        super(StreamListener, self).__init__()

    def on_data(self, data):
        """This is called when data are streamed in."""
        if (time.time() - self.start_time) < self.limit:
            datajson = json.loads(data)
            print (datajson)
            id = datajson['id']
            username = datajson['user']['screen_name']
            created_at = datajson['created_at']
            text = datajson['text'].strip().replace("\n", "")

            # process the geo-tags
            if datajson['coordinates'] == None:
                bbox = datajson['place']['bounding_box']['coordinates'][0]
                lng = (bbox[0][0] + bbox[2][0]) / 2.0
                lat = (bbox[0][1] + bbox[1][1]) / 2.0
            else:
                lng = datajson['coordinates']['coordinates'][0]
                lat = datajson['coordinates']['coordinates'][1]
            row = {
                'id': id,
                'username': username,
                'created_at': created_at,
                'lng': lng,
                'lat': lat,
                'text': text
            }

            print (row)
            self.writer.writerow(row)
        else:
            self.f.close()
            print ("finish.")
            return False


if __name__ == "__main__":
    # These are provided to you through the Twitter API after you create a account
    # register a Twitter App to get the keys and access tokens.
    output_file = "assets/geotags.csv"

    # Apply for your own Twitter API keys at https://developer.twitter.com/en/apply-for-access
    consumer_key = "AuqhYPEBSFigdrFzfqUzHoEov"
    consumer_secret = "drIf06K8SNpgtjBOv7WfRIfBySs5rsISIHuQKh2awuHGjZdsZQ"
    access_token = "179512083-toy8Ejm6j2BK8I7dkeYnp2V0r8t6yUFO92m10KRf"
    access_token_secret = "d6mTUs2FBFCwDbc9WHvMoBRjk2ISES0RVYDGWVIOGhpR3"


    myauth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    myauth.set_access_token(access_token, access_token_secret)

    # LOCATIONS are the longitude, latitude coordinate corners for a box that restricts the
    # geographic area from which you will stream tweets. The first two define the southwest
    # corner of the box and the second two define the northeast corner of the box.
    LOCATIONS = [-124.7771694, 24.520833, -66.947028, 49.384472,  # Contiguous US
                 -164.639405, 58.806859, -144.152365, 71.76871,  # Alaska
                 -160.161542, 18.776344, -154.641396, 22.878623]  # Hawaii

    stream_listener = StreamListener(time_limit=60, file=output_file)
    stream = tweepy.Stream(auth=myauth, listener=stream_listener)
    stream.filter(locations=LOCATIONS)
    stream.filter(track=['energy justice'], is_async=True)
# Out:
# {'created_at': 'Mon Apr 19 06:15:44 +0000 2021', 'id': 1384027919626821638, 'id_str': '1384027919626821638', 'text': 'Today I breathed a sigh of relief as I received my first vaccine. Feeling grateful. https://t.co/NzcLbStuJ0', 'display_text_range': [0, 83], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 
 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1453, 'friends_count': 2343, 'listed_count': 83, 'favourites_count': 1256, 'statuses_count': 87553, 'created_at': 'Sat Mar 08 19:15:11 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1347798398783651841/4VcJ4FGJ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1347798398783651841/4VcJ4FGJ_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': {'id': '33ff2516301663e7', 'url': 'https://api.twitter.com/1.1/geo/id/33ff2516301663e7.json', 'place_type': 'city', 'name': 'West Springfield', 'full_name': 'West Springfield, VA', 'country_code': 'US', 'country': 'United States', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-77.266126, 38.755163], [-77.266126, 38.821463], [-77.202928, 38.821463], [-77.202928, 38.755163]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'TaylorMcFayden', 'name': 'theouterskyrim ☭ 🏴🚩💥', 'id': 749570006, 'id_str': '749570006', 'indices': [0, 15]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1618812945315'}
# {'id': 1384027922244149257, 'username': 'JosephStanley82', 'created_at': 'Mon Apr 19 06:15:45 +0000 2021', 'lng': -77.234527, 'lat': 38.788313, 'text': '@TaylorMcFayden Did Shreveport best Chicago for the week?    Chicago tallied 67 shot, only 11 murdered.  They are improving.'}
# {'created_at': 'Mon Apr 19 06:15:45 +0000 2021', 'id': 1384027922357317635, 'id_str': '1384027922357317635', 'text': "@RowenaN5 @Murky__Meg God only knows. She'll probably use her pregnancy and claim she's been admitted to the hospit… https://t.co/q2xJAF8ikB", 'display_text_range': [22, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': 1384000976177090561, 'in_reply_to_status_id_str': '1384000976177090561', 'in_reply_to_user_id': 3549893368, 'in_reply_to_user_id_str': '3549893368', 'in_reply_to_screen_name': 'RowenaN5', 'user': {'id': 505252335, 'id_str': '505252335', 'name': 'Beachcomber', 'screen_name': 'KatyRemington1', 'location': '@ SS Kalifornia', 'url': None, 'description': 'Books nourish my mind.The sun, the sand and the sea nourish my soul and keep me sane. And the doggies give me a reason to get out of bed in the morning.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 599, 'friends_count': 473, 'listed_count': 5, 'favourites_count': 158774, 'statuses_count': 27459, 'created_at': 'Mon Feb 27 01:34:42 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1356634829371006979/c8PPxC7p_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1356634829371006979/c8PPxC7p_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/505252335/1612281923', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': {'id': '01c060cf466c6ce3', 'url': 'https://api.twitter.com/1.1/geo/id/01c060cf466c6ce3.json', 'place_type': 'city', 'name': 'Long Beach', 'full_name': 'Long Beach, CA', 'country_code': 'US', 'country': 'United States', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-118.250227, 33.732905], [-118.250227, 33.885438], [-118.063194, 33.885438], [-118.063194, 33.732905]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': "@RowenaN5 @Murky__Meg God only knows. She'll probably use her pregnancy and claim she's been admitted to the hospital for (fake) contractions,  bleeding,  who knows. Guarantee she'll use anything she can come up with,  but DON'T SHARE IT: IGNORE HER. DON'T REWARD HER WITH THE ATTENTION SHE SEEKS!", 'display_text_range': [22, 297], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'RowenaN5', 'name': 'Rowena N', 'id': 3549893368, 'id_str': '3549893368', 'indices': [0, 9]}, {'screen_name': 'Murky__Meg', 'name': 'ℳ𝓊𝓇𝓀𝓎 ℳ𝑒𝑔', 'id': 1033295852004102144, 'id_str': '1033295852004102144', 'indices': [10, 21]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co
er', 'name': 'MC HAMMER', 'id': 6273552, 'id_str': '6273552', 'indices': [107, 116]}, {'screen_name': 'thejackjacobss', 'name': 'Jack Jacobs', 'id': 1368433613683924992, 'id_str': '1368433613683924992', 'indices': [117, 132]}, {'screen_name': 'deon30', 'name': 'dennis williams', 'id': 90481796, 'id_str': '90481796', 'indices': [133, 140]}, {'screen_name': 'ICGNU', 'name': 'Hugh Smith', 'id': 197286361, 'id_str': '197286361', 'indices': [154, 160]}], 'symbols' ...
# {'id': 1384028162695127040, 'username': 'Carla_Patra', 'created_at': 'Mon Apr 19 06:16:42 +0000 2021', 'lng': -122.4359785, 'lat': 37.7706565, 'text': '@rothken Thank you, Ira Rothken, for your brilliant explanation/ conversation @joinClubhouse w/@jin_diesel… https://t.co/SPOfsSno8R'}
# {'created_at': 'Mon Apr 19 06:16:43 +0000 2021', 'id': 1384028164221898757, 'id_str': '1384028164221898757', 'text': 'Ain’t had one since the LoGo snack shop (or whatever that shit was called). I STILL miss soda (damn near 18 years l… https://t.co/VKoh3pwCoq', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 72904301, 'id_str': '72904301', 'name': 'Rahsaan Henderson ♎️', 'screen_name': 'libra10584', 'location': 'The City Of Angels, Cali', 'url': 'http://www.instagram.com/libra10584', 'description': 'Writer/Dreamer/Lover/Son/Brother/Friend/Co-Worker/Professional Wino... Snapchat: libra10584', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3623, 'friends_count': 4556, 'listed_count': 59, 'favourites_count': 24022, 'statuses_count': 128909, 'created_at': 'Wed Sep 09 17:24:57 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '1A1F1B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': True, 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1377142057077104642/umINqIcU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1377142057077104642/umINqIcU_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/72904301/1613939967', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': {'id': '3b77caf94bfc81fe', 'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json', 'place_type': 'city', 'name': 'Los Angeles', 'full_name': 'Los Angeles, CA', 'country_code': 'US', 'country': 'United States', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]]]}, 'attributes': {}}, 'contributors': None, 'quoted_status_id': 1384016992751943680, 'quoted_status_id_str': '1384016992751943680', 'quoted_status': {'created_at': 'Mon Apr 19 05:32:19 +0000 2021', 'id': 1384016992751943680, 'id_str': '1384016992751943680', 'text': 'Facts.', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 715213338020458496, 'id_str': '715213338020458496', 'name': 'Jesús Malverde', 'screen_name': 'DJTosin', 'location': None, 'url': None, 'description': 'A man that knows his own strength can afford to be gentle. #INTJ #LosHombresSonElPremio #5232', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1071, 'friends_count': 861, 'listed_count': 6, 'favourites_count': 1443, 'statuses_count': 118834, 'created_at': 'Wed Mar 30 16:25:22 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': '000000' ...
# {'id': 1384028164221898757, 'username': 'libra10584', 'created_at': 'Mon Apr 19 06:16:43 +0000 2021', 'lng': -118.4119065, 'lat': 34.0207895, 'text': 'Ain’t had one since the LoGo snack shop (or whatever that shit was called). I STILL miss soda (damn near 18 years l… https://t.co/VKoh3pwCoq'}
# {'created_at': 'Mon Apr 19 06:16:43 +0000 2021', 'id': 1384028167610855425, 'id_str': '1384028167610855425', 'text': 'I be old af now -.-', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id